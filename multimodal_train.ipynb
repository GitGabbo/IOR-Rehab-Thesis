# %%
import numpy as np
import extracted_data_reader
from tsai.all import *
from fastai.tabular.core import *
import time
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Training the model

# %%
# initialize variables
ex_number = 5
frame_number = "mean" # mean, max or min
epochs_number=5
target = "goal"

TARGETS_LABELS = ["goal", "head", "width", "shoulders", "trunk"]

# %%
# get training data
X = np.array(extracted_data_reader.read_data_ex(ex_number=ex_number, frame_number=frame_number))
Y = np.array(extracted_data_reader.read_target_ex(ex_number=ex_number))
y = np.array([y[TARGETS_LABELS.index(target)] for y in Y])

X.shape, y.shape
# Out:
# ((216, 18, 270), (216,))

# %%
# get features from timeseries data
ts_features = get_ts_features(X, y)

# view timeseries features
ts_features.head()
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:11<00:00,  1.78it/s]
#    0__sum_values  0__median   0__mean  0__length  0__standard_deviation  \
# 0     102.946788   0.380283  0.381284      270.0               0.003688
# 1     102.870717   0.380160  0.381003      270.0               0.003894
# 2     102.564568   0.379489  0.379869      270.0               0.002325
# 3     102.665563   0.379496  0.380243      270.0               0.002587
# 4     102.547645   0.379823  0.379806      270.0               0.001337
#
#    0__variance  0__root_mean_square  0__maximum  0__absolute_maximum  \
# 0     0.000014             0.381302    0.394004             0.394004
# 1     0.000015             0.381023    0.393243             0.393243
# 2     0.000005             0.379876    0.387312             0.387312
# 3     0.000007             0.380252    0.388383             0.388383
# 4     0.000002             0.379808    0.383341             0.383341
# ...

# %%
# get demographic data
df = []
df_dir = f"final_tab_data/ex{ex_number}/"
for file in sorted(os.listdir(df_dir)):
    df.append(pd.read_csv(os.path.join(df_dir, file)))
    
df = pd.concat(df, axis=0, ignore_index=True)

# view demographic data
df.head()
# Out:
#    Goal  Width  Head  Shoulders  Trunk  Score      id  age  height  weight  \
# 0     3      3     5          5      5     21  001 SJ   35     182    91.0
# 1     3      3     5          5      5     21  001 SJ   35     182    91.0
# 2     3      3     5          5      5     21  001 SJ   35     182    91.0
# 3     3      3     5          5      5     21  001 SJ   35     182    91.0
# 4     3      3     5          5      5     21  001 SJ   35     182    91.0
#
#     bmi gender
# 0  27.5      M
# 1  27.5      M
# 2  27.5      M
# 3  27.5      M
# 4  27.5      M

# %%
# merge timeseries data with demographic data
ts_features.insert(loc=0, column='age', value=df['age'])
ts_features.insert(loc=0, column='height', value=df['height'])
ts_features.insert(loc=0, column='weight', value=df['weight'])
ts_features.insert(loc=0, column='bmi', value=df['bmi'])
ts_features.insert(loc=0, column='gender', value=df['gender'])

# visualize merge
ts_features.head()
# Out:
#   gender   bmi  weight  height  age  0__sum_values  0__median   0__mean  \
# 0      M  27.5    91.0     182   35     102.946788   0.380283  0.381284
# 1      M  27.5    91.0     182   35     102.870717   0.380160  0.381003
# 2      M  27.5    91.0     182   35     102.564568   0.379489  0.379869
# 3      M  27.5    91.0     182   35     102.665563   0.379496  0.380243
# 4      M  27.5    91.0     182   35     102.547645   0.379823  0.379806
#
#    0__length  0__standard_deviation  0__variance  0__root_mean_square  \
# 0      270.0               0.003688     0.000014             0.381302
# 1      270.0               0.003894     0.000015             0.381023
# 2      270.0               0.002325     0.000005             0.379876
# 3      270.0               0.002587     0.000007             0.380252
# 4      270.0               0.001337     0.000002             0.379808
#
#    0__maximum  0__absolute_maximum  0__minimum  1__sum_values  1__median  \
# ...

# %%
# data to build data loaders
splits = get_splits(ts_features, n_splits=len(ts_features), shuffle=False, show_plot=False)
procs = [Categorify, FillMissing, Normalize]
cat_names = ['gender']
cont_names = list(ts_features.columns)[1:-5]
y_names = 'target'
y_block = CategoryBlock()

# %%
# fit the model

accs = []
# leave-one-out cross validation
for split in splits:
    to = TabularPandas(ts_features, cat_names=cat_names, cont_names=cont_names, y_names=y_names, splits=split, procs=procs, y_block=y_block, inplace=True)
    # create dataloader
    tab_dls = to.dataloaders(bs=32)
    # build model
    tab_model = build_tabular_model(TabModel, dls=tab_dls)
    # create learner
    learnTab = Learner(tab_dls, tab_model, metrics=accuracy)
    # fit
    learnTab.fit(epochs_number)
    # append accuracy
    accs.append(learnTab.validate()[1])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.238735</td>
#       <td>1.332395</td>
#       <td>0.000000</td>
#       <td>00:00</td>
# ...

# %%
# show mean accuracy
np.mean(np.array(accs))
# Out:
# 0.9120370370370371

# %%
# save metrics images of the model 
# image_base_name = f"C:/Users/Gabriele/Downloads/Uni/IOR-Rehab-Thesis/images/multi-models/ex{ex_number}/ex{ex_number}_{frame_number}_{target}"
# learnTab.recorder.plot_metrics(figname=f"{image_base_name}_metrics.png")
# learnTab.show_probas(figname=f"{image_base_name}_probas.png")
# interp = ClassificationInterpretation.from_learner(learnTab)
# interp.plot_confusion_matrix(figname=f"{image_base_name}_confusion_matrix.png")

# %%
# save the model
# learnTab.export(f"multi-models/ex{ex_number}_{frame_number}_{target}.pkl")
# learnTab.export(f"asd.pkl")

# %% [markdown]
# # Test the model

# %%
X_test = extracted_data_reader.read_data_ex(1, "mean", test=True)
test_f_ds = get_ts_features(np.array(X_test))
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 18/18 [00:16<00:00,  1.08it/s]

# %%
test_demo = pd.read_csv("demographic_data/test_demographic_info.csv")
test_f_ds.insert(loc=0, column='age', value=test_demo['age'])
test_f_ds.insert(loc=0, column='height', value=test_demo['height'])
test_f_ds.insert(loc=0, column='weight', value=test_demo['weight'])
test_f_ds.insert(loc=0, column='bmi', value=test_demo['bmi'])
test_f_ds.insert(loc=0, column='gender', value=test_demo['gender'])

# %%
# test_f_ds.insert(loc=0, column='target_4', value=[0]*len(test_f_ds))
# test_f_ds.insert(loc=0, column='target_3', value=[0]*len(test_f_ds))
# test_f_ds.insert(loc=0, column='target_2', value=[0]*len(test_f_ds))
# test_f_ds.insert(loc=0, column='target_1', value=[0]*len(test_f_ds))
# test_f_ds.insert(loc=185, column='target', value=[0]*len(test_f_ds))

# %%
test_f_ds.head()
# Out:
#   gender   bmi  weight  height  age  0__sum_values  0__median   0__mean  \
# 0      F  17.9      53     172   23      76.332330   0.464923  0.465441
# 1      F  17.9      53     172   23      79.943901   0.485883  0.487463
# 2      F  22.0      55     158   22      78.492654   0.478899  0.478614
# 3      F  22.0      55     158   22      78.200554   0.474718  0.476833
# 4      M  24.5      75     175   23      79.596442   0.485377  0.485344
#
#    0__length  0__standard_deviation  0__variance  0__root_mean_square  \
# 0      164.0               0.003240     0.000010             0.465452
# 1      164.0               0.005681     0.000032             0.487496
# 2      164.0               0.003463     0.000012             0.478626
# 3      164.0               0.007458     0.000056             0.476891
# 4      164.0               0.001836     0.000003             0.485348
#
#    0__maximum  0__absolute_maximum  0__minimum  1__sum_values  1__median  \
# ...

# %%
test_cont_names = list(test_f_ds.columns[2:])
to_test = TabularPandas(test_f_ds, cat_names=cat_names, cont_names=test_cont_names, y_block=y_block, procs=procs)
tab_test_dls = to_test.dataloaders()
test_dl = tab_dls.test_dl(test_f_ds)
preds, *_ = learnTab.get_preds(dl=test_dl)
preds = preds.numpy()
res = []
for p in preds:
    i = np.argmax(p)
    res.append(i+1)
res
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [1, 1, 1, 1, 1, 1]
